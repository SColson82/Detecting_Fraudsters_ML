# %%
import pandas as pd

# %%
X_train_df =  pd.read_csv("Datasets/X_train_G3tdtEn.csv")
X_train_df
# Out:
# c:\Users\Sharon\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (21,22,23,24,69,70,71,72,93,94,95,96,97,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#           ID                             item1  \
# 0      85517                         COMPUTERS
# 1      51113  COMPUTER PERIPHERALS ACCESSORIES
# 2      83008           TELEVISIONS HOME CINEMA
# 3      78712                         COMPUTERS
# 4      77846           TELEVISIONS HOME CINEMA
# ...      ...                               ...
# 92785  21243  COMPUTER PERIPHERALS ACCESSORIES
# 92786  45891                         COMPUTERS
# 92787  42613                 BEDROOM FURNITURE
# 92788  43567                         COMPUTERS
# 92789  68268           TELEVISIONS HOME CINEMA
#
# ...

# %%
y_train_df = pd.read_csv('Datasets/Y_train_2_XPXJDyy.csv')
y_train_df
# Out:
#        index     ID  fraud_flag
# 0          0  85517           0
# 1          1  51113           0
# 2          2  83008           0
# 3          3  78712           0
# 4          4  77846           0
# ...      ...    ...         ...
# 92785  92785  21243           0
# 92786  92786  45891           0
# 92787  92787  42613           0
# 92788  92788  43567           0
# 92789  92789  68268           0
#
# [92790 rows x 3 columns]

# %%
y_train_df['fraud_flag'].nunique()
# Out:
# 2

# %%
y_train_df['fraud_flag'].value_counts()
# Out:
# 0    91471
# 1     1319
# Name: fraud_flag, dtype: int64

# %%
y_test_df = pd.read_csv("Datasets/Y_test_random_2.csv")
y_test_df
# Out:
#        index      ID  fraud_flag
# 0          0   64707    0.165105
# 1          1   63919    0.284590
# 2          2   15664    0.497070
# 3          3    6626    0.491428
# 4          4   26766    0.994971
# ...      ...     ...         ...
# 23193  23193   63474    0.983022
# 23194  23194   80438    0.705398
# 23195  23195   29485    0.689810
# 23196  23196   59838    0.882254
# 23197  23197  110584    0.425888
#
# [23198 rows x 3 columns]

# %%
unique_df = pd.read_csv("fraud_unique_values_output.csv")
unique_df
# Out:
#         index  ID               fraud_flag                           item1  \
# 51091     130   1               TELEPHONES   FAX MACHINES & TWO-WAY RADIOS
# 85811     195   1                COMPUTERS                       COMPUTERS
# 839       217   1                COMPUTERS               FULFILMENT CHARGE
# 79246     552   1               TELEPHONES   FAX MACHINES & TWO-WAY RADIOS
# 52402     854   1                BED LINEN                       BED LINEN
# ...       ...  ..                      ...                             ...
# 79359  114032   1                COMPUTERS                             NaN
# 71896  114116   1  TELEVISIONS HOME CINEMA                             NaN
# 46840  114199   1                COMPUTERS                             NaN
# 12248  115021   1                COMPUTERS               FULFILMENT CHARGE
# 60671  115098   1                COMPUTERS                             NaN
#
# ...
